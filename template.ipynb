# %% [markdown]
# # [case] with [library]
#
# This is the notebook template, just section names here.
#
# Guidelines:
# - imports called when needed

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
# code here

# %% [markdown]
# ### Prepare

# %%
# code here

# %% [markdown]
# ## Model

# %% [markdown]
# ### Build (architecture)

# %%
# code here

# %% [markdown]
# ### Compile

# %%
# code here

# %% [markdown]
# ### Training loop (fit)

# %%
# code here

# %% [markdown]
# ## Results

# %% [markdown]
# ### Predictions

# %%
# code here

# %% [markdown]
# ### Evaluation (accuracy)

# %%
# code here

# %% [markdown]
# ### Show

# %%
# code here

# %% [markdown]
# Plot wrongs
